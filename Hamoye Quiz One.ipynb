# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url1 = r"https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv"

url2 = r"D:\FoodBalanceSheets_E_Africa_NOFLAG.csv"

# %%
df = pd.read_csv(url2, encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
array  = np.array([[94, 89, 63],[93, 92, 48],[92, 94, 56]])

# %%
array
# Out:
# array([[94, 89, 63],
#        [93, 92, 48],
#        [92, 94, 56]])

# %%
array[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
df.groupby('Item').sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %% [markdown]
# #### What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
df_wine = df[df['Item']== 'Wine']

# %%
d = df_wine.groupby('Item').sum()
d
# Out:
#       Area Code                                               Area  Item Code  \
# Item
# Wine      66206  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...    1319535
#
#       Element Code                                            Element  \
# Item
# Wine       1818328  ProductionImport QuantityStock VariationExport...
#
#                                                    Unit    Y2014    Y2015  \
# Item
# Wine  1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...  4497.36  4251.81
#
#         Y2016    Y2017    Y2018
# Item
# Wine  3872.09  4178.02  4039.32

# %%
d.head()
# Out:
#       Area Code                                               Area  Item Code  \
# Item
# Wine      66206  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...    1319535
#
#       Element Code                                            Element  \
# Item
# Wine       1818328  ProductionImport QuantityStock VariationExport...
#
#                                                    Unit    Y2014    Y2015  \
# Item
# Wine  1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...  4497.36  4251.81
#
#         Y2016    Y2017    Y2018
# Item
# Wine  3872.09  4178.02  4039.32

# %%
d.iat[0, 7]
# Out:
# 4251.81

# %%
d.index.get_loc('Wine')
# Out:
# 0

# %%
d.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Element Code', 'Element', 'Unit',
#        'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
col_labels = ['Y2015', 'Y2018']
col_index = [d.columns.get_loc(label) for label in col_labels]
col_index
# Out:
# [7, 10]

# %%
d.iat[0, 7]
# Out:
# 4251.81

# %%
d.iat[0, 10]
# Out:
# 4039.32

# %%
print(f"The total sum of Wine produced in 2015 is {d.iat[0,7]}.\n")
print(f"The total sum of Wine produced in 2018 is {d.iat[0,10]}.")
# Out:
# The total sum of Wine produced in 2015 is 4251.81.
#
# The total sum of Wine produced in 2018 is 4039.32.

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.Y2014.isnull().sum()
# Out:
# 1589

# %%
df.shape[0]
# Out:
# 60943

# %%
round((df['Y2014'].isnull().sum()/df.shape[0]*100), 3)
# Out:
# 2.607

# %%
print(f"The total number of missing data in year 2014 is: {df.Y2014.isnull().sum()}.\n")

print(f"The total percentage of missing data in year 2014 is: {round((df['Y2014'].isnull().sum()/df.shape[0]*100), 3)}%.")
# Out:
# The total number of missing data in year 2014 is: 1589.
#
# The total percentage of missing data in year 2014 is: 2.607%.

# %%
df.head(2)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %% [markdown]
# #### Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
df[df.Element == 'Processing']
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 19             4   Algeria       2905  Cereals - Excluding Beer          5131
# 35             4   Algeria       2511        Wheat and products          5131
# 51             4   Algeria       2805         Rice and products          5131
# 66             4   Algeria       2513       Barley and products          5131
# 81             4   Algeria       2514        Maize and products          5131
# ...          ...       ...        ...                       ...           ...
# 60694        181  Zimbabwe       2946               Animal fats          5131
# 60717        181  Zimbabwe       2743                     Cream          5131
# 60730        181  Zimbabwe       2737        Fats, Animals, Raw          5131
# 60789        181  Zimbabwe       2948   Milk - Excluding Butter          5131
# 60803        181  Zimbabwe       2848   Milk - Excluding Butter          5131
#
# ...

# %%
df.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
df_processing = df[df.Element == 'Processing']

df_processing.groupby('Element')['Y2017'].sum()[0]
# Out:
# 292836.0

# %%
print(f"The total number of the sum of processing in year 2017 is: {df_processing.groupby('Element')['Y2017'].sum()[0]}.")
# Out:
# The total number of the sum of processing in year 2017 is: 292836.0.

# %% [markdown]
# ##### Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
df[['Y2017','Area']].groupby('Area').sum().sort_values('Y2017', ascending = False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
df[['Y2017','Area']].groupby('Area').sum().max()
# Out:
# Y2017    1483268.23
# dtype: float64

# %%
print("The area with the largest sum in year 2017 is: Nigeria")
# Out:
# The area with the largest sum in year 2017 is: Nigeria

# %% [markdown]
# #### Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df[df.Element == 'Stock Variation']
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 13             4   Algeria       2905  Cereals - Excluding Beer          5072
# 29             4   Algeria       2511        Wheat and products          5072
# 45             4   Algeria       2805         Rice and products          5072
# 60             4   Algeria       2513       Barley and products          5072
# 75             4   Algeria       2514        Maize and products          5072
# ...          ...       ...        ...                       ...           ...
# 60842        181  Zimbabwe       2763              Pelagic Fish          5072
# 60853        181  Zimbabwe       2764        Marine Fish, Other          5072
# 60914        181  Zimbabwe       2928             Miscellaneous          5072
# 60924        181  Zimbabwe       2680               Infant food          5072
# 60934        181  Zimbabwe       2899             Miscellaneous          5072
#
# ...

# %%
df.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017']].agg([np.sum, np.max])
# Out:
#                                              Y2014                  Y2015  \
#                                                sum       amax         sum
# Element
# Domestic supply quantity                1996716.35  108756.00  2021493.55
# Export Quantity                          150020.64   39686.00   157614.47
# Fat supply quantity (g/capita/day)        10225.56      93.73    10235.74
# Feed                                     216927.89   29797.00   225050.22
# Food                                    1212332.49   49014.00  1232361.10
# Food supply (kcal/capita/day)            454257.00    3435.00   453383.00
# Food supply quantity (kg/capita/yr)       49650.63     428.27    49345.13
# Import Quantity                          274144.48   19582.00   267018.46
# Losses                                   153223.00    9807.00   155439.00
# Other uses (non-food)                     78718.13   12552.00    66254.41
# ...

# %%
df.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017']].sum().sort_values('Y2017', ascending = False)
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Production                              1931287.75  1947019.39  1943537.15
# Food                                    1212332.49  1232361.10  1247022.17
# Total Population - Both sexes           1031585.00  1058081.00  1085107.00
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Import Quantity                          274144.48   267018.46   286582.78
# Processing                               282923.00   287929.00   280631.00
# Feed                                     216927.89   225050.22   228958.65
# Export Quantity                          150020.64   157614.47   151920.46
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# ...

# %%
df.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017']].sum().loc[['Stock Variation']]
# Out:
#                     Y2014     Y2015     Y2016     Y2017
# Element
# Stock Variation  58749.83  34910.99  33140.12  54316.91

# %% [markdown]
# #### Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
df[['Y2017', 'Area']].groupby('Area').sum().sort_values('Y2017')
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %% [markdown]
# #### What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
df[['Y2017']].describe()
# Out:
#                Y2017
# count   59437.000000
# mean      140.917765
# std      1671.862359
# min     -1582.000000
# 25%         0.000000
# 50%         0.100000
# 75%         9.000000
# max    190873.000000

# %% [markdown]
# #### What is the total Protein supply quantity in Madagascar in 2015?

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df_protein_mada = df[(df.Element == 'Protein supply quantity (g/capita/day)') & (df.Area == 'Madagascar')]

# %%
df_protein_mada.head()
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30721           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30724           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30740           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30756           674  Protein supply quantity (g/capita/day)  g/capita/day
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 30718  44.45  43.26  43.35  43.94  44.17
# ...

# %%
df_protein_mada.groupby('Area')['Y2015'].sum()[0]
# Out:
# 173.05

# %%
print(f"The total Protein supply quantity in Madagascar in 2015 is: {df_protein_mada.groupby('Area')['Y2015'].sum()[0]}.")
# Out:
# The total Protein supply quantity in Madagascar in 2015 is: 173.05.

# %% [markdown]
# #### If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?

# %% [markdown]
# ### Consider the following list of tuples:
#
# y = [(2, 4), (7, 8), (1, 5, 9)]
#
# How would you assign element 8 from the list to a variable x?

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]
x
# Out:
# 8

# %% [markdown]
# ### Which year had the least correlation with ‘Element Code’?

# %%
df.head(1)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0

# %%
df1 = df[['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]

# %%
df1.corr()['Element Code'].sort_values(ascending = True)
# Out:
# Y2016           0.023444
# Y2015           0.023889
# Y2017           0.024254
# Y2018           0.024279
# Y2014           0.024457
# Element Code    1.000000
# Name: Element Code, dtype: float64

# %% [markdown]
# #### What is the total number of unique countries in the dataset?

# %%
df.Area.nunique()
# Out:
# 49

# %%
print(f"The total number of unique countries in the dataset is: {df.Area.nunique()}.")
# Out:
# The total number of unique countries in the dataset is: 49.

# %% [markdown]
# ##############################################################
